# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# TASK 2.1

# %% [markdown]
# As varaible states I load "Iris_data.npy" as "data" and "Iris_labels.npy" as labels
# In data there is:
# * Sepal length
# * Sepal width
# * Petal length
# * Petal width
# * 150 samples of Iris

# %%
data = np.load('./Iris_data.npy')
labels = np.load('./Iris_labels.npy')

x_feature = 0
y_feature = 1

# %%
plt.figure()
plt.scatter(data[:, x_feature], data[:, y_feature], c=labels)
plt.xlabel ('Sepal Width(cm)') 
plt.ylabel ('Sepal Length(cm)')
plt.title ('Fisher Iris Data Plot')
plt.show()

# %% [markdown]
# TASK 2.2

# %%
from sklearn.cluster import KMeans
fit
